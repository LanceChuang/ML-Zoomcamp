# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("laptops.csv")

# %%
len(dataset)
# Out:
# 2160

# %%
dataset
# Out:
#                                                  Laptop       Status   Brand  \
# 0     ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...          New    Asus
# 1     Alurin Go Start Intel Celeron N4020/8GB/256GB ...          New  Alurin
# 2     ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...          New    Asus
# 3     MSI Katana GF66 12UC-082XES Intel Core i7-1270...          New     MSI
# 4     HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...          New      HP
# ...                                                 ...          ...     ...
# 2155  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2156  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2157  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2158  Razer Book 13 Intel Evo Core i7-1165G7/16GB/1T...  Refurbished   Razer
# 2159  Razer Book FHD+ Intel Evo Core i7-1165G7/16GB/...  Refurbished   Razer
#
# ...

# %%
dell = dataset[
    dataset['Brand'] == 'Dell'
]
dell.describe().round(2)
# Out:
#          RAM  Storage  Screen  Final Price
# count  84.00    84.00   84.00        84.00
# mean   11.38   395.14   14.69      1153.84
# std     4.58   175.54    1.02       671.80
# min     4.00   128.00   13.00       379.00
# 25%     8.00   256.00   14.00       699.00
# 50%     8.00   256.00   14.50      1003.00
# 75%    16.00   512.00   15.60      1313.81
# max    32.00  1000.00   17.00      3936.00

# %%
dataset.nunique()
# Out:
# Laptop          2160
# Status             2
# Brand             27
# Model            121
# CPU               28
# RAM                9
# Storage           12
# Storage type       2
# GPU               44
# Screen            29
# Touch              2
# Final Price     1440
# dtype: int64

# %%
dataset.isnull().sum()
# Out:
# Laptop             0
# Status             0
# Brand              0
# Model              0
# CPU                0
# RAM                0
# Storage            0
# Storage type      42
# GPU             1371
# Screen             4
# Touch              0
# Final Price        0
# dtype: int64

# %%
dataset.describe().round(2)
# Out:
#            RAM  Storage   Screen  Final Price
# count  2160.00  2160.00  2156.00      2160.00
# mean     15.41   596.29    15.17      1312.64
# std       9.87   361.22     1.20       911.48
# min       4.00     0.00    10.10       201.05
# 25%       8.00   256.00    14.00       661.08
# 50%      16.00   512.00    15.60      1031.95
# 75%      16.00  1000.00    15.60      1708.97
# max     128.00  4000.00    18.00      7150.47

# %%
# 50% is median 
m = 15.60
most_frequent_screen = dataset['Screen'].mode().iloc[0]
dataset['Screen'] = dataset['Screen'].fillna(most_frequent_screen)

# %%
dataset['Screen'].mode().iloc[0]
# Out:
# 15.6

# %%
dataset = dataset[
    (dataset['Brand'] == 'Innjoo')
]
dataset
# Out:
#                                                  Laptop Status   Brand Model  \
# 1478  InnJoo Voom Excellence Intel Celeron N4020/8GB...    New  Innjoo  Voom
# 1479  InnJoo Voom Excellence Pro Intel Celeron N4020...    New  Innjoo  Voom
# 1480  Innjoo Voom Intel Celeron N3350/4GB/64GB eMMC/...    New  Innjoo  Voom
# 1481  Innjoo Voom Laptop Max Intel Celeron N3350/6GB...    New  Innjoo  Voom
# 1482  Innjoo Voom Laptop Pro Intel Celeron N3350/6GB...    New  Innjoo  Voom
# 1483  Innjoo Voom Pro Intel Celeron N3350/6GB/128GB ...    New  Innjoo  Voom
#
#                 CPU  RAM  Storage Storage type  GPU  Screen Touch  Final Price
# 1478  Intel Celeron    8      256          SSD  NaN    15.6    No       311.37
# 1479  Intel Celeron    8      512          SSD  NaN    15.6    No       392.55
# 1480  Intel Celeron    4       64         eMMC  NaN    14.1    No       251.40
# 1481  Intel Celeron    6       64         eMMC  NaN    14.1    No       383.61
# ...

# %%
df_innjoo = dataset[['RAM', 'Storage', 'Screen']]
X = df_innjoo.values
# Compute XTX
XTX = np.dot(X.T, X)
# Compute the inverse of XTX
XTX_inv = np.linalg.inv(XTX)
# Create the array y
y = np.array([1100, 1300, 800, 900, 1000, 1100])
w = np.dot(np.dot(XTX_inv, X.T ), y)
# Calculate the sum of elements in w
sum_w = np.sum(w)

print("Sum of w:", sum_w)
# Out:
# Sum of w: 91.2998806299555
